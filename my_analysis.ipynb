# %%
import pandas as pd
df = pd.read_csv("/content/population (1).csv")
df = df[['Country Name', 'Year', 'Value']]
df = df[df['Country Name'] == 'Aruba']
print (df)
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.plot(aruba['Year'], aruba['Value'], marker='o')
plt.title('Population of Aruba Over Years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)
df.to_csv("/content/population (1).csv" ,index=False)
plt.show()
# Out:
#    Country Name  Year     Value
# 0         Aruba  1960   54922.0
# 1         Aruba  1961   55578.0
# 2         Aruba  1962   56320.0
# 3         Aruba  1963   57002.0
# 4         Aruba  1964   57619.0
# ..          ...   ...       ...
# 59        Aruba  2019  109203.0
# 60        Aruba  2020  108587.0
# 61        Aruba  2021  107700.0
# 62        Aruba  2022  107310.0
# 63        Aruba  2023  107359.0
#
# [64 rows x 3 columns]
